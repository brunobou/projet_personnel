# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,RidgeCV,LassoCV,ElasticNetCV
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error

# %%
Train=pd.read_csv("df_train_dicho.csv",index_col=0)

# %%
Target=pd.read_csv('df_test_dicho.csv',index_col=0)

# %%
Train.head()#1460 lignes
# Out:
#     MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# Id
# 1           60         5            2        0       0      0         0
# 2           20         5            2        0       0      0         0
# 3           60         5            2        1       0      0         1
# 4           70         5            2        0       0      0         1
# 5           60         5            2        1       0      0         1
#
#     LandContour  Utilities  LotConfig  ...  PoolArea  PoolQC  Fence  \
# Id                                     ...
# 1             0          0          0  ...         0       4      4
# 2             0          0          3  ...         0       4      4
# 3             0          0          0  ...         0       4      4
# 4             0          0          1  ...         0       4      4
# 5             0          0          3  ...         0       4      4
#
# ...

# %%
Target.head()#1459 lignes
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# Id
# 1461          20         4            2        1       0      0         0
# 1462          20         5            2        1       0      0         1
# 1463          60         5            2        1       0      0         1
# 1464          60         5            2        0       0      0         1
# 1465         120         5            1        0       0      0         1
#
#       LandContour  Utilities  LotConfig  ...  PoolArea  PoolQC  Fence  \
# Id                                       ...
# 1461            0          0          0  ...         0       4      1
# 1462            0          0          1  ...         0       4      4
# 1463            0          0          0  ...         0       4      1
# 1464            0          0          0  ...         0       4      4
# 1465            2          0          0  ...         0       4      4
#
# ...

# %%
scaler=StandardScaler()

# %%
Target["SalePrice"]=0

# %%
Target.head()
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# Id
# 1461          20         4            2        1       0      0         0
# 1462          20         5            2        1       0      0         1
# 1463          60         5            2        1       0      0         1
# 1464          60         5            2        0       0      0         1
# 1465         120         5            1        0       0      0         1
#
#       LandContour  Utilities  LotConfig  ...  PoolArea  PoolQC  Fence  \
# Id                                       ...
# 1461            0          0          0  ...         0       4      1
# 1462            0          0          1  ...         0       4      4
# 1463            0          0          0  ...         0       4      1
# 1464            0          0          0  ...         0       4      4
# 1465            2          0          0  ...         0       4      4
#
# ...

# %%
X = pd.concat([Train,Target])

# %%
X.head()
# Out:
#     MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# Id
# 1           60         5            2        0       0      0         0
# 2           20         5            2        0       0      0         0
# 3           60         5            2        1       0      0         1
# 4           70         5            2        0       0      0         1
# 5           60         5            2        1       0      0         1
#
#     LandContour  Utilities  LotConfig  ...  PoolArea  PoolQC  Fence  \
# Id                                     ...
# 1             0          0          0  ...         0       4      4
# 2             0          0          3  ...         0       4      4
# 3             0          0          0  ...         0       4      4
# 4             0          0          1  ...         0       4      4
# 5             0          0          3  ...         0       4      4
#
# ...

# %%
Comp = pd.DataFrame(scaler.fit_transform(X),index=X.index,columns=X.columns)

# %%
X_train = Comp.iloc[:1460,:]
X_target = Comp.iloc[1460:,:]

# %%
X_target.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1459 entries, 1461 to 2919
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1459 non-null   float64
#  1   MSZoning       1459 non-null   float64
#  2   LotFrontage    1459 non-null   float64
#  3   LotArea        1459 non-null   float64
#  4   Street         1459 non-null   float64
#  5   Alley          1459 non-null   float64
#  6   LotShape       1459 non-null   float64
#  7   LandContour    1459 non-null   float64
#  8   Utilities      1459 non-null   float64
#  9   LotConfig      1459 non-null   float64
#  10  LandSlope      1459 non-null   float64
#  11  Neighborhood   1459 non-null   float64
#  12  Condition1     1459 non-null   float64
#  13  Condition2     1459 non-null   float64
#  14  BldgType       1459 non-null   float64
#  15  HouseStyle     1459 non-null   float64
#  16  OverallQual    1459 non-null   float64
# ...

# %%
X['BsmtHalfBath'].value_counts()
# Out:
# 0.0    2744
# 1.0     171
# 2.0       4
# Name: BsmtHalfBath, dtype: int64

# %%
X_train.head()
# Out:
#     MSSubClass  MSZoning  LotFrontage   LotArea    Street     Alley  LotShape  \
# Id
# 1     0.073375 -0.120682     0.501674 -0.737254 -0.064238 -0.243025 -0.701291
# 2    -0.872563 -0.120682     0.501674 -0.737254 -0.064238 -0.243025 -0.701291
# 3     0.073375 -0.120682     0.501674  0.791710 -0.064238 -0.243025  1.016637
# 4     0.309859 -0.120682     0.501674 -0.737254 -0.064238 -0.243025  1.016637
# 5     0.073375 -0.120682     0.501674  0.791710 -0.064238 -0.243025  1.016637
#
#     LandContour  Utilities  LotConfig  ...  PoolArea    PoolQC     Fence  \
# Id                                     ...
# 1     -0.306146   -0.02618  -0.538603  ... -0.068692  0.063796  0.469867
# 2     -0.306146   -0.02618   3.341462  ... -0.068692  0.063796  0.469867
# 3     -0.306146   -0.02618  -0.538603  ... -0.068692  0.063796  0.469867
# 4     -0.306146   -0.02618   0.754752  ... -0.068692  0.063796  0.469867
# 5     -0.306146   -0.02618   3.341462  ... -0.068692  0.063796  0.469867
#
# ...

# %%
X_target.head()
# Out:
#       MSSubClass  MSZoning  LotFrontage   LotArea    Street     Alley  \
# Id
# 1461   -0.872563 -1.073090     0.501674  0.791710 -0.064238 -0.243025
# 1462   -0.872563 -0.120682     0.501674  0.791710 -0.064238 -0.243025
# 1463    0.073375 -0.120682     0.501674  0.791710 -0.064238 -0.243025
# 1464    0.073375 -0.120682     0.501674 -0.737254 -0.064238 -0.243025
# 1465    1.492282 -0.120682    -0.660936 -0.737254 -0.064238 -0.243025
#
#       LotShape  LandContour  Utilities  LotConfig  ...  PoolArea    PoolQC  \
# Id                                                 ...
# 1461 -0.701291    -0.306146   -0.02618  -0.538603  ... -0.068692  0.063796
# 1462  1.016637    -0.306146   -0.02618   0.754752  ... -0.068692  0.063796
# 1463  1.016637    -0.306146   -0.02618  -0.538603  ... -0.068692  0.063796
# 1464  1.016637    -0.306146   -0.02618  -0.538603  ... -0.068692  0.063796
# 1465  1.016637     2.992544   -0.02618  -0.538603  ... -0.068692  0.063796
#
# ...

# %%
x_train=X_train.drop(["SalePrice"],axis=1)
y_train=X_train["SalePrice"]
x_target=X_target.drop(["SalePrice"],axis=1)
y_target=X_target["SalePrice"]

# %%
ml= ElasticNetCV(l1_ratio=(0.01,0.05,0.1,0.2,0.4,0.5,0.6,0.8,1),n_alphas=1000,cv=10)

# %%
ml.fit(x_train,y_train)
# Out:
# ElasticNetCV(cv=10, l1_ratio=(0.01, 0.05, 0.1, 0.2, 0.4, 0.5, 0.6, 0.8, 1),
#              n_alphas=1000)

# %%
ml.l1_ratio_
# Out:
# 0.1

# %%
ml.alpha_
# Out:
# 0.032366943697249156

# %%
ml.score(x_train,y_train)
# Out:
# 0.8401508027200023

# %%
y_train_pred = ml.predict(x_train)

# %%
y_target_pred= ml.predict(x_target)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [36], in <module>
# ----> 1 y_target_pred= ml.predict(x_target)
#
# File C:\ProgramData\miniforge3\envs\my-env\lib\site-packages\sklearn\linear_model\_base.py:362, in LinearModel.predict(self, X)
#     348 def predict(self, X):
#     349     """
#     350     Predict using the linear model.
#     351
#    (...)
#     360         Returns predicted values.
#     361     """
# --> 362     return self._decision_function(X)
#
# File C:\ProgramData\miniforge3\envs\my-env\lib\site-packages\sklearn\linear_model\_base.py:345, in LinearModel._decision_function(self, X)
#     342 def _decision_function(self, X):
#     343     check_is_fitted(self)
# --> 345     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     346     return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#
# ...
