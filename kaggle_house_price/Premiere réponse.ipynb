# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,RidgeCV,LassoCV,ElasticNetCV
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error

# %%
Train=pd.read_csv("df_train_dicho.csv",index_col=0)

# %%
Target=pd.read_csv('df_test_dicho.csv',index_col=0)

# %%
Train.head()#1460 lignes
# Out:
#     MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# Id
# 1           60         5            2        0       0      0         0
# 2           20         5            2        0       0      0         0
# 3           60         5            2        1       0      0         1
# 4           70         5            2        0       0      0         1
# 5           60         5            2        1       0      0         1
#
#     LandContour  Utilities  LotConfig  ...  PoolArea  PoolQC  Fence  \
# Id                                     ...
# 1             0          0          0  ...         0       4      4
# 2             0          0          3  ...         0       4      4
# 3             0          0          0  ...         0       4      4
# 4             0          0          1  ...         0       4      4
# 5             0          0          3  ...         0       4      4
#
#     MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1             5        0       2    2008         0              0     208500
# 2             5        0       5    2007         0              0     181500
# 3             5        0       9    2008         0              0     223500
# 4             5        0       2    2006         0              1     140000
# 5             5        0      12    2008         0              0     250000
#
# [5 rows x 80 columns]

# %%
Target.head()#1459 lignes
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# Id
# 1461          20         4            2        1       0      0         0
# 1462          20         5            2        1       0      0         1
# 1463          60         5            2        1       0      0         1
# 1464          60         5            2        0       0      0         1
# 1465         120         5            1        0       0      0         1
#
#       LandContour  Utilities  LotConfig  ...  ScreenPorch  PoolArea  PoolQC  \
# Id                                       ...
# 1461            0          0          0  ...            2         0       4
# 1462            0          0          1  ...            0         0       4
# 1463            0          0          0  ...            0         0       4
# 1464            0          0          0  ...            0         0       4
# 1465            2          0          0  ...            2         0       4
#
#       Fence  MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition
# Id
# 1461      1            5        0       6    2010         0              0
# 1462      4            1        3       6    2010         0              0
# 1463      1            5        0       3    2010         0              0
# 1464      4            5        0       6    2010         0              0
# 1465      4            5        0       1    2010         0              0
#
# [5 rows x 79 columns]

# %%
scaler=StandardScaler()

# %%
Target["SalePrice"]=0

# %%
Target.head()
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# Id
# 1461          20         4            2        1       0      0         0
# 1462          20         5            2        1       0      0         1
# 1463          60         5            2        1       0      0         1
# 1464          60         5            2        0       0      0         1
# 1465         120         5            1        0       0      0         1
#
#       LandContour  Utilities  LotConfig  ...  PoolArea  PoolQC  Fence  \
# Id                                       ...
# 1461            0          0          0  ...         0       4      1
# 1462            0          0          1  ...         0       4      4
# 1463            0          0          0  ...         0       4      1
# 1464            0          0          0  ...         0       4      4
# 1465            2          0          0  ...         0       4      4
#
#       MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1461            5        0       6    2010         0              0          0
# 1462            1        3       6    2010         0              0          0
# 1463            5        0       3    2010         0              0          0
# 1464            5        0       6    2010         0              0          0
# 1465            5        0       1    2010         0              0          0
#
# [5 rows x 80 columns]

# %%
X = pd.concat([Train,Target])

# %%
X.head()
# Out:
#     MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# Id
# 1           60         5            2        0       0      0         0
# 2           20         5            2        0       0      0         0
# 3           60         5            2        1       0      0         1
# 4           70         5            2        0       0      0         1
# 5           60         5            2        1       0      0         1
#
#     LandContour  Utilities  LotConfig  ...  PoolArea  PoolQC  Fence  \
# Id                                     ...
# 1             0          0          0  ...         0       4      4
# 2             0          0          3  ...         0       4      4
# 3             0          0          0  ...         0       4      4
# 4             0          0          1  ...         0       4      4
# 5             0          0          3  ...         0       4      4
#
#     MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1             5        0       2    2008         0              0     208500
# 2             5        0       5    2007         0              0     181500
# 3             5        0       9    2008         0              0     223500
# 4             5        0       2    2006         0              1     140000
# 5             5        0      12    2008         0              0     250000
#
# [5 rows x 80 columns]

# %%
Comp = pd.DataFrame(scaler.fit_transform(X),index=X.index,columns=X.columns)

# %%
X_train = Comp.iloc[:1460,:]
X_target = Comp.iloc[1460:,:]

# %%
X_target.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1459 entries, 1461 to 2919
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1459 non-null   float64
#  1   MSZoning       1459 non-null   float64
#  2   LotFrontage    1459 non-null   float64
#  3   LotArea        1459 non-null   float64
#  4   Street         1459 non-null   float64
#  5   Alley          1459 non-null   float64
#  6   LotShape       1459 non-null   float64
#  7   LandContour    1459 non-null   float64
#  8   Utilities      1459 non-null   float64
#  9   LotConfig      1459 non-null   float64
#  10  LandSlope      1459 non-null   float64
#  11  Neighborhood   1459 non-null   float64
#  12  Condition1     1459 non-null   float64
#  13  Condition2     1459 non-null   float64
#  14  BldgType       1459 non-null   float64
#  15  HouseStyle     1459 non-null   float64
#  16  OverallQual    1459 non-null   float64
#  17  OverallCond    1459 non-null   float64
#  18  YearBuilt      1459 non-null   float64
#  19  YearRemodAdd   1459 non-null   float64
#  20  RoofStyle      1459 non-null   float64
#  21  RoofMatl       1459 non-null   float64
#  22  Exterior1st    1459 non-null   float64
#  23  Exterior2nd    1459 non-null   float64
#  24  MasVnrType     1459 non-null   float64
#  25  MasVnrArea     1459 non-null   float64
#  26  ExterQual      1459 non-null   float64
#  27  ExterCond      1459 non-null   float64
#  28  Foundation     1459 non-null   float64
#  29  BsmtQual       1459 non-null   float64
#  30  BsmtCond       1459 non-null   float64
#  31  BsmtExposure   1459 non-null   float64
#  32  BsmtFinType1   1459 non-null   float64
#  33  BsmtFinSF1     1459 non-null   float64
#  34  BsmtFinType2   1459 non-null   float64
#  35  BsmtFinSF2     1459 non-null   float64
#  36  BsmtUnfSF      1459 non-null   float64
#  37  TotalBsmtSF    1459 non-null   float64
#  38  Heating        1459 non-null   float64
#  39  HeatingQC      1459 non-null   float64
#  40  CentralAir     1459 non-null   float64
#  41  Electrical     1459 non-null   float64
#  42  1stFlrSF       1459 non-null   float64
#  43  2ndFlrSF       1459 non-null   float64
#  44  LowQualFinSF   1459 non-null   float64
#  45  GrLivArea      1459 non-null   float64
#  46  BsmtFullBath   1459 non-null   float64
#  47  BsmtHalfBath   1459 non-null   float64
#  48  FullBath       1459 non-null   float64
#  49  HalfBath       1459 non-null   float64
#  50  BedroomAbvGr   1459 non-null   float64
#  51  KitchenAbvGr   1459 non-null   float64
#  52  KitchenQual    1459 non-null   float64
#  53  TotRmsAbvGrd   1459 non-null   float64
#  54  Functional     1459 non-null   float64
#  55  Fireplaces     1459 non-null   float64
#  56  FireplaceQu    1459 non-null   float64
#  57  GarageType     1459 non-null   float64
#  58  GarageYrBlt    1459 non-null   float64
#  59  GarageFinish   1459 non-null   float64
#  60  GarageCars     1459 non-null   float64
#  61  GarageArea     1459 non-null   float64
#  62  GarageQual     1459 non-null   float64
#  63  GarageCond     1459 non-null   float64
#  64  PavedDrive     1459 non-null   float64
#  65  WoodDeckSF     1459 non-null   float64
#  66  OpenPorchSF    1459 non-null   float64
#  67  EnclosedPorch  1459 non-null   float64
#  68  3SsnPorch      1459 non-null   float64
#  69  ScreenPorch    1459 non-null   float64
#  70  PoolArea       1459 non-null   float64
#  71  PoolQC         1459 non-null   float64
#  72  Fence          1459 non-null   float64
#  73  MiscFeature    1459 non-null   float64
#  74  MiscVal        1459 non-null   float64
#  75  MoSold         1459 non-null   float64
#  76  YrSold         1459 non-null   float64
#  77  SaleType       1459 non-null   float64
#  78  SaleCondition  1459 non-null   float64
#  79  SalePrice      1459 non-null   float64
# dtypes: float64(80)
# memory usage: 923.3 KB

# %%
X['BsmtHalfBath'].value_counts()
# Out:
# 0.0    2744
# 1.0     171
# 2.0       4
# Name: BsmtHalfBath, dtype: int64

# %%
X_train.head()
# Out:
#     MSSubClass  MSZoning  LotFrontage   LotArea    Street    Alley  LotShape  \
# Id
# 1     0.067331 -0.118486     0.494336 -0.747127 -0.064249 -0.25356 -0.701900
# 2    -0.873616 -0.118486     0.494336 -0.747127 -0.064249 -0.25356 -0.701900
# 3     0.067331 -0.118486     0.494336  0.859995 -0.064249 -0.25356  1.052249
# 4     0.302568 -0.118486     0.494336 -0.747127 -0.064249 -0.25356  1.052249
# 5     0.067331 -0.118486     0.494336  0.859995 -0.064249 -0.25356  1.052249
#
#     LandContour  Utilities  LotConfig  ...  PoolArea    PoolQC     Fence  \
# Id                                     ...
# 1     -0.308471  -0.018512  -0.522154  ... -0.066884  0.055063  0.477059
# 2     -0.308471  -0.018512   3.372655  ... -0.066884  0.055063  0.477059
# 3     -0.308471  -0.018512  -0.522154  ... -0.066884  0.055063  0.477059
# 4     -0.308471  -0.018512   0.776115  ... -0.066884  0.055063  0.477059
# 5     -0.308471  -0.018512   3.372655  ... -0.066884  0.055063  0.477059
#
#     MiscFeature   MiscVal    MoSold    YrSold  SaleType  SaleCondition  \
# Id
# 1      0.188401 -0.177238 -1.552184  0.157646 -0.358033      -0.394298
# 2      0.188401 -0.177238 -0.446925 -0.602962 -0.358033      -0.394298
# 3      0.188401 -0.177238  1.026753  0.157646 -0.358033      -0.394298
# 4      0.188401 -0.177238 -1.552184 -1.363569 -0.358033       0.284732
# 5      0.188401 -0.177238  2.132012  0.157646 -0.358033      -0.394298
#
#     SalePrice
# Id
# 1    1.108288
# 2    0.854715
# 3    1.249162
# 4    0.464963
# 5    1.498039
#
# [5 rows x 80 columns]

# %%
X_target.head()
# Out:
#       MSSubClass  MSZoning  LotFrontage   LotArea    Street    Alley  \
# Id
# 1461   -0.873616 -1.035884     0.494336  0.859995 -0.064249 -0.25356
# 1462   -0.873616 -0.118486     0.494336  0.859995 -0.064249 -0.25356
# 1463    0.067331 -0.118486     0.494336  0.859995 -0.064249 -0.25356
# 1464    0.067331 -0.118486     0.494336 -0.747127 -0.064249 -0.25356
# 1465    1.478753 -0.118486    -0.690366 -0.747127 -0.064249 -0.25356
#
#       LotShape  LandContour  Utilities  LotConfig  ...  PoolArea    PoolQC  \
# Id                                                 ...
# 1461 -0.701900    -0.308471  -0.018512  -0.522154  ... -0.066884  0.055063
# 1462  1.052249    -0.308471  -0.018512   0.776115  ... -0.066884  0.055063
# 1463  1.052249    -0.308471  -0.018512  -0.522154  ... -0.066884  0.055063
# 1464  1.052249    -0.308471  -0.018512  -0.522154  ... -0.066884  0.055063
# 1465  1.052249     3.045077  -0.018512  -0.522154  ... -0.066884  0.055063
#
#          Fence  MiscFeature    MiscVal    MoSold   YrSold  SaleType  \
# Id
# 1461 -1.987605     0.188401  -0.177238 -0.078505  1.67886 -0.358033
# 1462  0.477059    -9.676048  11.319582 -0.078505  1.67886 -0.358033
# 1463 -1.987605     0.188401  -0.177238 -1.183764  1.67886 -0.358033
# 1464  0.477059     0.188401  -0.177238 -0.078505  1.67886 -0.358033
# 1465  0.477059     0.188401  -0.177238 -1.920603  1.67886 -0.358033
#
#       SaleCondition  SalePrice
# Id
# 1461      -0.394298  -0.849861
# 1462      -0.394298  -0.849861
# 1463      -0.394298  -0.849861
# 1464      -0.394298  -0.849861
# 1465      -0.394298  -0.849861
#
# [5 rows x 80 columns]

# %%
x_train=X_train.drop(["SalePrice"],axis=1)
y_train=X_train["SalePrice"]
x_target=X_target.drop(["SalePrice"],axis=1)
y_target=X_target["SalePrice"]

# %%
ml= ElasticNetCV(l1_ratio=(0.01,0.05,0.1,0.2,0.4,0.5,0.6,0.8,1),n_alphas=1000,cv=10)

# %%
ml.fit(x_train,y_train)
# Out:
# ElasticNetCV(cv=10, l1_ratio=(0.01, 0.05, 0.1, 0.2, 0.4, 0.5, 0.6, 0.8, 1),
#              n_alphas=1000)

# %%
ml.l1_ratio_
# Out:
# 0.05

# %%
ml.alpha_
# Out:
# 0.051171669458928946

# %%
ml.score(x_train,y_train)
# Out:
# 0.8408660866046949

# %%
y_train_pred = ml.predict(x_train)

# %%
y_target_pred= ml.predict(x_target)

# %%
mean_squared_error(y_train,y_train_pred)
# Out:
# 0.08852177989076773

# %%
# inversion scaler transform

# %%
#X_train x_target et y_target_pred

# %%
X_target_pred = x_target

# %%
X_target_pred["SalePrice"]= y_target_pred

# %%
X_target_pred.head()
# Out:
#       MSSubClass  MSZoning  LotFrontage   LotArea    Street    Alley  \
# Id
# 1461   -0.873616 -1.035884     0.494336  0.859995 -0.064249 -0.25356
# 1462   -0.873616 -0.118486     0.494336  0.859995 -0.064249 -0.25356
# 1463    0.067331 -0.118486     0.494336  0.859995 -0.064249 -0.25356
# 1464    0.067331 -0.118486     0.494336 -0.747127 -0.064249 -0.25356
# 1465    1.478753 -0.118486    -0.690366 -0.747127 -0.064249 -0.25356
#
#       LotShape  LandContour  Utilities  LotConfig  ...  PoolArea    PoolQC  \
# Id                                                 ...
# 1461 -0.701900    -0.308471  -0.018512  -0.522154  ... -0.066884  0.055063
# 1462  1.052249    -0.308471  -0.018512   0.776115  ... -0.066884  0.055063
# 1463  1.052249    -0.308471  -0.018512  -0.522154  ... -0.066884  0.055063
# 1464  1.052249    -0.308471  -0.018512  -0.522154  ... -0.066884  0.055063
# 1465  1.052249     3.045077  -0.018512  -0.522154  ... -0.066884  0.055063
#
#          Fence  MiscFeature    MiscVal    MoSold   YrSold  SaleType  \
# Id
# 1461 -1.987605     0.188401  -0.177238 -0.078505  1.67886 -0.358033
# 1462  0.477059    -9.676048  11.319582 -0.078505  1.67886 -0.358033
# 1463 -1.987605     0.188401  -0.177238 -1.183764  1.67886 -0.358033
# 1464  0.477059     0.188401  -0.177238 -0.078505  1.67886 -0.358033
# 1465  0.477059     0.188401  -0.177238 -1.920603  1.67886 -0.358033
#
#       SaleCondition  SalePrice
# Id
# 1461      -0.394298   0.199306
# 1462      -0.394298   0.690445
# 1463      -0.394298   0.731330
# 1464      -0.394298   0.942833
# 1465      -0.394298   1.070793
#
# [5 rows x 80 columns]

# %%
Comp_pred = pd.concat([X_train,X_target_pred])

# %%
Comp_pred.head()
# Out:
#     MSSubClass  MSZoning  LotFrontage   LotArea    Street    Alley  LotShape  \
# Id
# 1     0.067331 -0.118486     0.494336 -0.747127 -0.064249 -0.25356 -0.701900
# 2    -0.873616 -0.118486     0.494336 -0.747127 -0.064249 -0.25356 -0.701900
# 3     0.067331 -0.118486     0.494336  0.859995 -0.064249 -0.25356  1.052249
# 4     0.302568 -0.118486     0.494336 -0.747127 -0.064249 -0.25356  1.052249
# 5     0.067331 -0.118486     0.494336  0.859995 -0.064249 -0.25356  1.052249
#
#     LandContour  Utilities  LotConfig  ...  PoolArea    PoolQC     Fence  \
# Id                                     ...
# 1     -0.308471  -0.018512  -0.522154  ... -0.066884  0.055063  0.477059
# 2     -0.308471  -0.018512   3.372655  ... -0.066884  0.055063  0.477059
# 3     -0.308471  -0.018512  -0.522154  ... -0.066884  0.055063  0.477059
# 4     -0.308471  -0.018512   0.776115  ... -0.066884  0.055063  0.477059
# 5     -0.308471  -0.018512   3.372655  ... -0.066884  0.055063  0.477059
#
#     MiscFeature   MiscVal    MoSold    YrSold  SaleType  SaleCondition  \
# Id
# 1      0.188401 -0.177238 -1.552184  0.157646 -0.358033      -0.394298
# 2      0.188401 -0.177238 -0.446925 -0.602962 -0.358033      -0.394298
# 3      0.188401 -0.177238  1.026753  0.157646 -0.358033      -0.394298
# 4      0.188401 -0.177238 -1.552184 -1.363569 -0.358033       0.284732
# 5      0.188401 -0.177238  2.132012  0.157646 -0.358033      -0.394298
#
#     SalePrice
# Id
# 1    1.108288
# 2    0.854715
# 3    1.249162
# 4    0.464963
# 5    1.498039
#
# [5 rows x 80 columns]

# %%
X_pred = pd.DataFrame(scaler.inverse_transform(Comp_pred),index=Comp_pred.index,columns=Comp_pred.columns)

# %%
X_pred.head()
# Out:
#     MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# Id
# 1         60.0       5.0          2.0      0.0     0.0    0.0       0.0
# 2         20.0       5.0          2.0      0.0     0.0    0.0       0.0
# 3         60.0       5.0          2.0      1.0     0.0    0.0       1.0
# 4         70.0       5.0          2.0      0.0     0.0    0.0       1.0
# 5         60.0       5.0          2.0      1.0     0.0    0.0       1.0
#
#     LandContour     Utilities     LotConfig  ...  PoolArea  PoolQC  Fence  \
# Id                                           ...
# 1           0.0  1.084202e-19  5.551115e-17  ...       0.0     4.0    4.0
# 2           0.0  1.084202e-19  3.000000e+00  ...       0.0     4.0    4.0
# 3           0.0  1.084202e-19  5.551115e-17  ...       0.0     4.0    4.0
# 4           0.0  1.084202e-19  1.000000e+00  ...       0.0     4.0    4.0
# 5           0.0  1.084202e-19  3.000000e+00  ...       0.0     4.0    4.0
#
#     MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1           5.0      0.0     2.0  2008.0       0.0            0.0   208500.0
# 2           5.0      0.0     5.0  2007.0       0.0            0.0   181500.0
# 3           5.0      0.0     9.0  2008.0       0.0            0.0   223500.0
# 4           5.0      0.0     2.0  2006.0       0.0            1.0   140000.0
# 5           5.0      0.0    12.0  2008.0       0.0            0.0   250000.0
#
# [5 rows x 80 columns]

# %%
X_pred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 1 to 2919
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     2919 non-null   float64
#  1   MSZoning       2919 non-null   float64
#  2   LotFrontage    2919 non-null   float64
#  3   LotArea        2919 non-null   float64
#  4   Street         2919 non-null   float64
#  5   Alley          2919 non-null   float64
#  6   LotShape       2919 non-null   float64
#  7   LandContour    2919 non-null   float64
#  8   Utilities      2919 non-null   float64
#  9   LotConfig      2919 non-null   float64
#  10  LandSlope      2919 non-null   float64
#  11  Neighborhood   2919 non-null   float64
#  12  Condition1     2919 non-null   float64
#  13  Condition2     2919 non-null   float64
#  14  BldgType       2919 non-null   float64
#  15  HouseStyle     2919 non-null   float64
#  16  OverallQual    2919 non-null   float64
#  17  OverallCond    2919 non-null   float64
#  18  YearBuilt      2919 non-null   float64
#  19  YearRemodAdd   2919 non-null   float64
#  20  RoofStyle      2919 non-null   float64
#  21  RoofMatl       2919 non-null   float64
#  22  Exterior1st    2919 non-null   float64
#  23  Exterior2nd    2919 non-null   float64
#  24  MasVnrType     2919 non-null   float64
#  25  MasVnrArea     2919 non-null   float64
#  26  ExterQual      2919 non-null   float64
#  27  ExterCond      2919 non-null   float64
#  28  Foundation     2919 non-null   float64
#  29  BsmtQual       2919 non-null   float64
#  30  BsmtCond       2919 non-null   float64
#  31  BsmtExposure   2919 non-null   float64
#  32  BsmtFinType1   2919 non-null   float64
#  33  BsmtFinSF1     2919 non-null   float64
#  34  BsmtFinType2   2919 non-null   float64
#  35  BsmtFinSF2     2919 non-null   float64
#  36  BsmtUnfSF      2919 non-null   float64
#  37  TotalBsmtSF    2919 non-null   float64
#  38  Heating        2919 non-null   float64
#  39  HeatingQC      2919 non-null   float64
#  40  CentralAir     2919 non-null   float64
#  41  Electrical     2919 non-null   float64
#  42  1stFlrSF       2919 non-null   float64
#  43  2ndFlrSF       2919 non-null   float64
#  44  LowQualFinSF   2919 non-null   float64
#  45  GrLivArea      2919 non-null   float64
#  46  BsmtFullBath   2919 non-null   float64
#  47  BsmtHalfBath   2919 non-null   float64
#  48  FullBath       2919 non-null   float64
#  49  HalfBath       2919 non-null   float64
#  50  BedroomAbvGr   2919 non-null   float64
#  51  KitchenAbvGr   2919 non-null   float64
#  52  KitchenQual    2919 non-null   float64
#  53  TotRmsAbvGrd   2919 non-null   float64
#  54  Functional     2919 non-null   float64
#  55  Fireplaces     2919 non-null   float64
#  56  FireplaceQu    2919 non-null   float64
#  57  GarageType     2919 non-null   float64
#  58  GarageYrBlt    2919 non-null   float64
#  59  GarageFinish   2919 non-null   float64
#  60  GarageCars     2919 non-null   float64
#  61  GarageArea     2919 non-null   float64
#  62  GarageQual     2919 non-null   float64
#  63  GarageCond     2919 non-null   float64
#  64  PavedDrive     2919 non-null   float64
#  65  WoodDeckSF     2919 non-null   float64
#  66  OpenPorchSF    2919 non-null   float64
#  67  EnclosedPorch  2919 non-null   float64
#  68  3SsnPorch      2919 non-null   float64
#  69  ScreenPorch    2919 non-null   float64
#  70  PoolArea       2919 non-null   float64
#  71  PoolQC         2919 non-null   float64
#  72  Fence          2919 non-null   float64
#  73  MiscFeature    2919 non-null   float64
#  74  MiscVal        2919 non-null   float64
#  75  MoSold         2919 non-null   float64
#  76  YrSold         2919 non-null   float64
#  77  SaleType       2919 non-null   float64
#  78  SaleCondition  2919 non-null   float64
#  79  SalePrice      2919 non-null   float64
# dtypes: float64(80)
# memory usage: 1.8 MB

# %%
Price_pred = X_pred.iloc[1460:,:]

# %%
Price_pred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1459 entries, 1461 to 2919
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1459 non-null   float64
#  1   MSZoning       1459 non-null   float64
#  2   LotFrontage    1459 non-null   float64
#  3   LotArea        1459 non-null   float64
#  4   Street         1459 non-null   float64
#  5   Alley          1459 non-null   float64
#  6   LotShape       1459 non-null   float64
#  7   LandContour    1459 non-null   float64
#  8   Utilities      1459 non-null   float64
#  9   LotConfig      1459 non-null   float64
#  10  LandSlope      1459 non-null   float64
#  11  Neighborhood   1459 non-null   float64
#  12  Condition1     1459 non-null   float64
#  13  Condition2     1459 non-null   float64
#  14  BldgType       1459 non-null   float64
#  15  HouseStyle     1459 non-null   float64
#  16  OverallQual    1459 non-null   float64
#  17  OverallCond    1459 non-null   float64
#  18  YearBuilt      1459 non-null   float64
#  19  YearRemodAdd   1459 non-null   float64
#  20  RoofStyle      1459 non-null   float64
#  21  RoofMatl       1459 non-null   float64
#  22  Exterior1st    1459 non-null   float64
#  23  Exterior2nd    1459 non-null   float64
#  24  MasVnrType     1459 non-null   float64
#  25  MasVnrArea     1459 non-null   float64
#  26  ExterQual      1459 non-null   float64
#  27  ExterCond      1459 non-null   float64
#  28  Foundation     1459 non-null   float64
#  29  BsmtQual       1459 non-null   float64
#  30  BsmtCond       1459 non-null   float64
#  31  BsmtExposure   1459 non-null   float64
#  32  BsmtFinType1   1459 non-null   float64
#  33  BsmtFinSF1     1459 non-null   float64
#  34  BsmtFinType2   1459 non-null   float64
#  35  BsmtFinSF2     1459 non-null   float64
#  36  BsmtUnfSF      1459 non-null   float64
#  37  TotalBsmtSF    1459 non-null   float64
#  38  Heating        1459 non-null   float64
#  39  HeatingQC      1459 non-null   float64
#  40  CentralAir     1459 non-null   float64
#  41  Electrical     1459 non-null   float64
#  42  1stFlrSF       1459 non-null   float64
#  43  2ndFlrSF       1459 non-null   float64
#  44  LowQualFinSF   1459 non-null   float64
#  45  GrLivArea      1459 non-null   float64
#  46  BsmtFullBath   1459 non-null   float64
#  47  BsmtHalfBath   1459 non-null   float64
#  48  FullBath       1459 non-null   float64
#  49  HalfBath       1459 non-null   float64
#  50  BedroomAbvGr   1459 non-null   float64
#  51  KitchenAbvGr   1459 non-null   float64
#  52  KitchenQual    1459 non-null   float64
#  53  TotRmsAbvGrd   1459 non-null   float64
#  54  Functional     1459 non-null   float64
#  55  Fireplaces     1459 non-null   float64
#  56  FireplaceQu    1459 non-null   float64
#  57  GarageType     1459 non-null   float64
#  58  GarageYrBlt    1459 non-null   float64
#  59  GarageFinish   1459 non-null   float64
#  60  GarageCars     1459 non-null   float64
#  61  GarageArea     1459 non-null   float64
#  62  GarageQual     1459 non-null   float64
#  63  GarageCond     1459 non-null   float64
#  64  PavedDrive     1459 non-null   float64
#  65  WoodDeckSF     1459 non-null   float64
#  66  OpenPorchSF    1459 non-null   float64
#  67  EnclosedPorch  1459 non-null   float64
#  68  3SsnPorch      1459 non-null   float64
#  69  ScreenPorch    1459 non-null   float64
#  70  PoolArea       1459 non-null   float64
#  71  PoolQC         1459 non-null   float64
#  72  Fence          1459 non-null   float64
#  73  MiscFeature    1459 non-null   float64
#  74  MiscVal        1459 non-null   float64
#  75  MoSold         1459 non-null   float64
#  76  YrSold         1459 non-null   float64
#  77  SaleType       1459 non-null   float64
#  78  SaleCondition  1459 non-null   float64
#  79  SalePrice      1459 non-null   float64
# dtypes: float64(80)
# memory usage: 923.3 KB

# %%
Res_pred = Price_pred["SalePrice"]

# %%
Res_pred.head()
# Out:
# Id
# 1461    111713.282053
# 1462    164008.913753
# 1463    168362.239045
# 1464    190882.716994
# 1465    204507.621421
# Name: SalePrice, dtype: float64

# %%
Res_pred.to_csv("Submission_1.csv")
